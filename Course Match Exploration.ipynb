# %%
import pandas as pd

# %%
pd.read_csv('dartmouth_majors.csv').iloc[14].values
# Out:
# array(['Computer Science', 'Computer Science Department',
#        'Bachelor of  Arts',
#        'http://dartmouth.smartcatalogiq.com/en/current/orc/Departments-Programs-Undergraduate/Computer-Science'],
#       dtype=object)

# %%
computer_science_courses = pd.read_csv('computer_science_courses_with_descriptions.csv')

# %%
computer_science_courses.head(5)
# Out:
#    dept                                       course_title  \
# 0  COSC  COSC 1 Introduction to Programming and Computa...
# 1  COSC  COSC 2 Programming for Interactive Audio-Visua...
# 2  COSC  COSC 10 Problem Solving via Object-Oriented Pr...
# 3  COSC  COSC 16 Introduction to Computational Neurosci...
# 4  COSC                COSC 19.01 Writing about Technology
#
#                                           course_url course_code  \
# 0  https://dartmouth.smartcatalogiq.com/en/curren...       COSC1
# 1  https://dartmouth.smartcatalogiq.com/en/curren...       COSC2
# 2  https://dartmouth.smartcatalogiq.com/en/curren...      COSC10
# 3  https://dartmouth.smartcatalogiq.com/en/curren...      COSC16
# 4  https://dartmouth.smartcatalogiq.com/en/curren...   COSC19.01
#
#                                          description  \
# 0  This course introduces computational concepts ...
# 1  This course presents topics related to interac...
# ...

# %%
from dotenv import load_dotenv
import os

# Set the OpenAI API key
load_dotenv()
openai_api_key = os.getenv("OPENAI_API_KEY")
print(openai_api_key)
# Out:
# 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
